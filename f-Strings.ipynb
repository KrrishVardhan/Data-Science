# %%
name = "Krrish"
age = 19
print(f"Hello my Name is {name} and iam {age} years old")
# Out:
# Hello my Name is Krrish and iam 19 years old

# %%
print(f"{'Feature':<15}{'Importance':>10}")
print(f"{'-'*25}")
print(f"{'Age':<15}{0.876:>10.3f}")
print(f"{'Income':<15}{0.654:>10.3f}")
# Out:
# Feature        Importance
# -------------------------
# Age                 0.876
# Income              0.654
