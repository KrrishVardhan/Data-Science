# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#         Name  Age   Department           Position  Years_Experience  Salary  \
# 0      Shrii   28  Engineering   Senior Developer                 5   95000
# 1      Samay   32    Marketing  Marketing Manager                 7   88000
# 2    Bhargav   26  Engineering   Junior Developer                 2   65000
# 3     Adarsh   35      Finance  Financial Analyst                10  105000
# 4      Prabh   29       Design      Lead Designer                 6   82000
# 5  MoneyBhai   41      Finance                CFO                15  185000
# 6      Krish   24  Engineering             Intern                 1   45000
#
#    Performance_Rating  Projects_Completed  Hours_Worked_Per_Week  Education  \
# 0                 4.5                  23                     42    Masters
# 1                 4.2                  18                     38  Bachelors
# 2                 4.0                  12                     40  Bachelors
# 3                 4.8                  31                     45        MBA
# 4                 4.6                  27                     39  Bachelors
# 5                 4.9                  45                     50        MBA
# 6                 3.8                   8                     35  Bachelors
#
#     Location                       Skills
# 0  Bangalore      Python|JavaScript|React
# 1     Mumbai        SEO|Analytics|Content
# 2       Pune              Java|SQL|Spring
# 3      Delhi        Excel|SAP|Forecasting
# 4  Hyderabad            Figma|Adobe|UI/UX
# 5     Mumbai  Strategy|Finance|Leadership
# 6  Bangalore              Python|HTML|CSS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   7 non-null      object
#  1   Age                    7 non-null      int64
#  2   Department             7 non-null      object
#  3   Position               7 non-null      object
#  4   Years_Experience       7 non-null      int64
#  5   Salary                 7 non-null      int64
#  6   Performance_Rating     7 non-null      float64
#  7   Projects_Completed     7 non-null      int64
#  8   Hours_Worked_Per_Week  7 non-null      int64
#  9   Education              7 non-null      object
#  10  Location               7 non-null      object
#  11  Skills                 7 non-null      object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 804.0+ bytes

# %%
df.loc[1]
# Out:
# Name                                     Samay
# Age                                         32
# Department                           Marketing
# Position                     Marketing Manager
# Years_Experience                             7
# Salary                                   88000
# Performance_Rating                         4.2
# Projects_Completed                          18
# Hours_Worked_Per_Week                       38
# Education                            Bachelors
# Location                                Mumbai
# Skills                   SEO|Analytics|Content
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Name                                     Samay
# Age                                         32
# Department                           Marketing
# Position                     Marketing Manager
# Years_Experience                             7
# Salary                                   88000
# Performance_Rating                         4.2
# Projects_Completed                          18
# Hours_Worked_Per_Week                       38
# Education                            Bachelors
# Location                                Mumbai
# Skills                   SEO|Analytics|Content
# Name: 1, dtype: object

# %%
df.loc[3,"Education"]
# Out:
# 'MBA'

# %%
df.iloc[3,9]
# Out:
# 'MBA'

# %%
# For .loc[0:2] 0,1,2 will be output
df.loc[0:2, ["Name", "Education"]]
# Out:
#       Name  Education
# 0    Shrii    Masters
# 1    Samay  Bachelors
# 2  Bhargav  Bachelors

# %%
# For .iloc[0:2] 0,1 will be output
df.iloc[0:2, 0:3]
# Out:
#     Name  Age   Department
# 0  Shrii   28  Engineering
# 1  Samay   32    Marketing
