# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
if type(a) is int:
    print(a)
# Out:
# 10

# %%
b = "10034983"
c = "29389212"
print(b+c)
# Out:
# 1003498329389212

# %%
# typecasting
print(int(b) + int(c))
# Out:
# 39424195
